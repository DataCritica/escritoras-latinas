# %% [markdown]
# ### Imports

# %%
import re
import numpy as np
import pandas as pd
import escritoras_latinas.data.load as load
import escritoras_latinas.data.process as process
"""
Natural Language Processing
"""
# NLTK - Sentence Tokenizer
from nltk.tokenize import sent_tokenize
# GSDMM - Topic Modeling
from gsdmm import MovieGroupProcess

# %% [markdown]
# ### Load data

# %%
data_raw = load.data_raw
data_processed = load.data_processed
data_entries = load.data_entries

# %% [markdown]
# ### Read data

# %%
# Read 'csv' file as dataframe
df = pd.read_csv(f'{data_entries}')

# Show shape of dataframe
df.shape
# Out:
# (1116, 1)

# %%
# Convert dataframe to list
entries = df.values.tolist()
# Convert to item on list
entries = [str(entry) for entry in entries]
# Clean list content
entries = [re.sub(r'(^.*?\))', '', entry) for entry in entries]

# %% [markdown]
# ### Process data with NLP (Natural Language Processing)

# %%
# Initialize a MovieGroupProcess
mgp = MovieGroupProcess(K=5, alpha=0.1, beta=0.1, n_iters=30)


# Define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    top_words = []
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        top_words.append(sort_dicts)
        print("\nCluster %s: %s"%(cluster, sort_dicts))
    return top_words

# %%
docs_list = []
vocab_list = []
for i in range(len(entries)):
    # Tokenize text into sentences
    sents = sent_tokenize(entries[i])
    # Tokenize sentences into words
    data = list(process.sent_to_words(sents))
    # Remove stopwords in Spanish
    docs = process.remove_stopwords(data)
    docs_list.append(docs)
    # Filter unique words
    vocab = set(x for doc in docs for x in doc)
    vocab_list.append(vocab)

# %%
clusters = []
for i in range(len(entries)):
    # Fit the model
    y = mgp.fit(docs_list[i], len(vocab_list[i]))

    # Number of documents per topic
    doc_count = np.array(mgp.cluster_doc_count)
    # Topics sorted by the number of document they are allocated to
    top_index = doc_count.argsort()[-15:][::-1]

    # Get top words in topics
    topwords = top_words(mgp.cluster_word_distribution, top_index, 3)
    # Filter first element from tuples
    # for sublist in topwords:
    #     clusters.append(list(map(lambda x: x[0], sublist)))
    clusters.append(topwords)
# Out:
# In stage 0: transferred 17 clusters with 5 clusters populated
# In stage 1: transferred 5 clusters with 5 clusters populated
# In stage 2: transferred 7 clusters with 4 clusters populated
# In stage 3: transferred 9 clusters with 5 clusters populated
# In stage 4: transferred 8 clusters with 4 clusters populated
# In stage 5: transferred 8 clusters with 5 clusters populated
# In stage 6: transferred 8 clusters with 5 clusters populated
# In stage 7: transferred 8 clusters with 5 clusters populated
# In stage 8: transferred 6 clusters with 5 clusters populated
# In stage 9: transferred 5 clusters with 5 clusters populated
# In stage 10: transferred 4 clusters with 5 clusters populated
# In stage 11: transferred 2 clusters with 5 clusters populated
# In stage 12: transferred 6 clusters with 5 clusters populated
# In stage 13: transferred 5 clusters with 5 clusters populated
# In stage 14: transferred 4 clusters with 5 clusters populated
# In stage 15: transferred 4 clusters with 5 clusters populated
# In stage 16: transferred 6 clusters with 5 clusters populated
# In stage 17: transferred 5 clusters with 5 clusters populated
# In stage 18: transferred 6 clusters with 5 clusters populated
# In stage 19: transferred 7 clusters with 5 clusters populated
# In stage 20: transferred 4 clusters with 5 clusters populated
# In stage 21: transferred 4 clusters with 5 clusters populated
# In stage 22: transferred 7 clusters with 5 clusters populated
# In stage 23: transferred 8 clusters with 5 clusters populated
# In stage 24: transferred 7 clusters with 5 clusters populated
# In stage 25: transferred 8 clusters with 4 clusters populated
# In stage 26: transferred 2 clusters with 5 clusters populated
# In stage 27: transferred 9 clusters with 5 clusters populated
# In stage 28: transferred 6 clusters with 5 clusters populated
# In stage 29: transferred 6 clusters with 4 clusters populated
#
# Cluster 2: [('méxico', 4), ('poesía', 3), ('internacional', 3)]
#
# Cluster 4: [('poeta', 1), ('venezolana', 1), ('reside', 1)]
#
# Cluster 3: [('poesía', 4), ('internacional', 4), ('festival', 3)]
#
# Cluster 0: [('asociación', 6), ('escritores', 6), ('antología', 5)]
#
# Cluster 1: []
# In stage 0: transferred 2 clusters with 5 clusters populated
# In stage 1: transferred 1 clusters with 5 clusters populated
# In stage 2: transferred 0 clusters with 5 clusters populated
# In stage 3: transferred 0 clusters with 5 clusters populated
# In stage 4: transferred 0 clusters with 5 clusters populated
# In stage 5: transferred 0 clusters with 5 clusters populated
# In stage 6: transferred 0 clusters with 5 clusters populated
# In stage 7: transferred 0 clusters with 5 clusters populated
# In stage 8: transferred 0 clusters with 5 clusters populated
# In stage 9: transferred 0 clusters with 5 clusters populated
# In stage 10: transferred 0 clusters with 5 clusters populated
# In stage 11: transferred 1 clusters with 5 clusters populated
# In stage 12: transferred 1 clusters with 5 clusters populated
# In stage 13: transferred 0 clusters with 5 clusters populated
# In stage 14: transferred 0 clusters with 5 clusters populated
# In stage 15: transferred 0 clusters with 5 clusters populated
# In stage 16: transferred 0 clusters with 5 clusters populated
# In stage 17: transferred 0 clusters with 5 clusters populated
# In stage 18: transferred 0 clusters with 5 clusters populated
# In stage 19: transferred 0 clusters with 5 clusters populated
# In stage 20: transferred 0 clusters with 5 clusters populated
# In stage 21: transferred 0 clusters with 5 clusters populated
# In stage 22: transferred 0 clusters with 5 clusters populated
# In stage 23: transferred 0 clusters with 5 clusters populated
# In stage 24: transferred 0 clusters with 5 clusters populated
# In stage 25: transferred 0 clusters with 5 clusters populated
# In stage 26: transferred 0 clusters with 5 clusters populated
# Converged.  Breaking out.
#
# Cluster 2: [('méxico', 4), ('poesía', 3), ('internacional', 3)]
#
# Cluster 4: [('venezolana', 2), ('poeta', 1), ('reside', 1)]
#
# Cluster 3: [('poesía', 4), ('internacional', 4), ('festival', 3)]
#
# Cluster 0: [('asociación', 7), ('escritores', 7), ('mérida', 6)]
#
# Cluster 1: [('socióloga', 1), ('doctora', 1), ('educación', 1)]
# In stage 0: transferred 26 clusters with 5 clusters populated
# In stage 1: transferred 15 clusters with 5 clusters populated
# In stage 2: transferred 9 clusters with 5 clusters populated
# In stage 3: transferred 4 clusters with 5 clusters populated
# In stage 4: transferred 7 clusters with 5 clusters populated
# In stage 5: transferred 9 clusters with 5 clusters populated
# In stage 6: transferred 8 clusters with 5 clusters populated
# In stage 7: transferred 8 clusters with 5 clusters populated
# In stage 8: transferred 9 clusters with 5 clusters populated
# In stage 9: transferred 8 clusters with 5 clusters populated
# In stage 10: transferred 10 clusters with 5 clusters populated
# In stage 11: transferred 4 clusters with 5 clusters populated
# In stage 12: transferred 5 clusters with 5 clusters populated
# In stage 13: transferred 10 clusters with 5 clusters populated
# In stage 14: transferred 8 clusters with 5 clusters populated
# In stage 15: transferred 8 clusters with 5 clusters populated
# In stage 16: transferred 8 clusters with 5 clusters populated
# In stage 17: transferred 8 clusters with 5 clusters populated
# In stage 18: transferred 8 clusters with 5 clusters populated
# In stage 19: transferred 6 clusters with 5 clusters populated
# In stage 20: transferred 8 clusters with 5 clusters populated
# In stage 21: transferred 8 clusters with 5 clusters populated
# In stage 22: transferred 11 clusters with 5 clusters populated
# In stage 23: transferred 9 clusters with 5 clusters populated
# In stage 24: transferred 7 clusters with 5 clusters populated
# In stage 25: transferred 5 clusters with 5 clusters populated
# In stage 26: transferred 7 clusters with 5 clusters populated
# In stage 27: transferred 8 clusters with 5 clusters populated
# In stage 28: transferred 10 clusters with 5 clusters populated
# In stage 29: transferred 3 clusters with 5 clusters populated
#
# Cluster 4: [('infantil', 6), ('venezolana', 4), ('cuento', 4)]
#
# Cluster 2: [('méxico', 4), ('encuentro', 4), ('niños', 4)]
#
# Cluster 1: [('premio', 9), ('cuentos', 7), ('cuento', 5)]
#
# Cluster 3: [('poesía', 6), ('letras', 5), ('internacional', 4)]
#
# Cluster 0: [('asociación', 7), ('escritores', 7), ('mérida', 6)]

# %%
# Create empty list
clusters = []
topics = []

for i in range(5):
    # Tokenize text into sentences
    sents = sent_tokenize(entries[i])
    # Tokenize sentences into words
    data = list(process.sent_to_words(sents))
    # Remove stopwords in Spanish
    docs = process.remove_stopwords(data)
    # Filter unique words
    vocab = set(x for doc in docs for x in doc)

    # Fit the model
    y = mgp.fit(docs, len(vocab))

    # Number of documents per topic
    doc_count = np.array(mgp.cluster_doc_count)
    # Topics sorted by the number of document they are allocated to
    top_index = doc_count.argsort()[-15:][::-1]

    # Get top words in topics
    topwords = top_words(mgp.cluster_word_distribution, top_index, 5)

    # Filter first element from tuples
    for sublist in topwords:
        clusters.append(list(map(lambda x: x[0], sublist)))
    # Flatten list of lists
    flat_clusters = [item for sublist in clusters for item in sublist]

    topics.append(flat_clusters)
    clusters.clear()
# Out:
# In stage 0: transferred 15 clusters with 5 clusters populated
# In stage 1: transferred 7 clusters with 5 clusters populated
# In stage 2: transferred 6 clusters with 5 clusters populated
# In stage 3: transferred 4 clusters with 5 clusters populated
# In stage 4: transferred 4 clusters with 5 clusters populated
# In stage 5: transferred 6 clusters with 5 clusters populated
# In stage 6: transferred 6 clusters with 5 clusters populated
# In stage 7: transferred 4 clusters with 5 clusters populated
# In stage 8: transferred 1 clusters with 5 clusters populated
# In stage 9: transferred 4 clusters with 5 clusters populated
# In stage 10: transferred 5 clusters with 5 clusters populated
# In stage 11: transferred 4 clusters with 5 clusters populated
# In stage 12: transferred 6 clusters with 5 clusters populated
# In stage 13: transferred 6 clusters with 5 clusters populated
# In stage 14: transferred 5 clusters with 5 clusters populated
# In stage 15: transferred 5 clusters with 5 clusters populated
# In stage 16: transferred 7 clusters with 5 clusters populated
# In stage 17: transferred 8 clusters with 5 clusters populated
# In stage 18: transferred 8 clusters with 5 clusters populated
# In stage 19: transferred 9 clusters with 5 clusters populated
# In stage 20: transferred 6 clusters with 5 clusters populated
# In stage 21: transferred 6 clusters with 5 clusters populated
# In stage 22: transferred 7 clusters with 5 clusters populated
# In stage 23: transferred 8 clusters with 5 clusters populated
# In stage 24: transferred 5 clusters with 5 clusters populated
# In stage 25: transferred 5 clusters with 5 clusters populated
# In stage 26: transferred 7 clusters with 5 clusters populated
# In stage 27: transferred 6 clusters with 5 clusters populated
# In stage 28: transferred 7 clusters with 5 clusters populated
# In stage 29: transferred 7 clusters with 5 clusters populated
#
# Cluster 3: [('universidad', 1436), ('literatura', 847), ('nacional', 588), ('escritora', 518), ('estudios', 444)]
#
# Cluster 2: [('libro', 527), ('novela', 499), ('obra', 441), ('años', 432), ('poesía', 359)]
#
# Cluster 1: [('años', 398), ('mujeres', 244), ('nacional', 229), ('mujer', 210), ('año', 205)]
#
# Cluster 0: [('poesía', 426), ('libro', 358), ('premio', 347), ('obra', 257), ('méxico', 247)]
#
# Cluster 4: [('em', 394), ('do', 280), ('da', 272), ('reimpresión', 232), ('com', 182)]
# In stage 0: transferred 3 clusters with 5 clusters populated
# In stage 1: transferred 1 clusters with 5 clusters populated
# In stage 2: transferred 0 clusters with 5 clusters populated
# In stage 3: transferred 0 clusters with 5 clusters populated
# In stage 4: transferred 0 clusters with 5 clusters populated
# In stage 5: transferred 0 clusters with 5 clusters populated
# In stage 6: transferred 0 clusters with 5 clusters populated
# In stage 7: transferred 0 clusters with 5 clusters populated
# In stage 8: transferred 1 clusters with 5 clusters populated
# In stage 9: transferred 0 clusters with 5 clusters populated
# In stage 10: transferred 1 clusters with 5 clusters populated
# In stage 11: transferred 0 clusters with 5 clusters populated
# In stage 12: transferred 0 clusters with 5 clusters populated
# In stage 13: transferred 1 clusters with 5 clusters populated
# In stage 14: transferred 1 clusters with 5 clusters populated
# In stage 15: transferred 1 clusters with 5 clusters populated
# In stage 16: transferred 1 clusters with 5 clusters populated
# In stage 17: transferred 1 clusters with 5 clusters populated
# In stage 18: transferred 1 clusters with 5 clusters populated
# In stage 19: transferred 1 clusters with 5 clusters populated
# In stage 20: transferred 1 clusters with 5 clusters populated
# In stage 21: transferred 0 clusters with 5 clusters populated
# In stage 22: transferred 0 clusters with 5 clusters populated
# In stage 23: transferred 0 clusters with 5 clusters populated
# In stage 24: transferred 1 clusters with 5 clusters populated
# In stage 25: transferred 1 clusters with 5 clusters populated
# In stage 26: transferred 0 clusters with 5 clusters populated
# Converged.  Breaking out.
#
# Cluster 3: [('universidad', 1437), ('literatura', 847), ('nacional', 588), ('escritora', 518), ('estudios', 444)]
#
# Cluster 2: [('libro', 527), ('novela', 499), ('obra', 441), ('años', 432), ('poesía', 359)]
#
# Cluster 1: [('años', 398), ('mujeres', 244), ('nacional', 229), ('mujer', 210), ('año', 205)]
#
# Cluster 0: [('poesía', 426), ('libro', 358), ('premio', 347), ('obra', 257), ('méxico', 247)]
#
# Cluster 4: [('em', 394), ('do', 280), ('da', 272), ('reimpresión', 232), ('com', 182)]
# In stage 0: transferred 24 clusters with 5 clusters populated
# In stage 1: transferred 2 clusters with 5 clusters populated
# In stage 2: transferred 4 clusters with 5 clusters populated
# In stage 3: transferred 4 clusters with 5 clusters populated
# In stage 4: transferred 6 clusters with 5 clusters populated
# In stage 5: transferred 5 clusters with 5 clusters populated
# In stage 6: transferred 5 clusters with 5 clusters populated
# In stage 7: transferred 2 clusters with 5 clusters populated
# In stage 8: transferred 4 clusters with 5 clusters populated
# In stage 9: transferred 6 clusters with 5 clusters populated
# In stage 10: transferred 5 clusters with 5 clusters populated
# In stage 11: transferred 6 clusters with 5 clusters populated
# In stage 12: transferred 4 clusters with 5 clusters populated
# In stage 13: transferred 1 clusters with 5 clusters populated
# In stage 14: transferred 4 clusters with 5 clusters populated
# In stage 15: transferred 5 clusters with 5 clusters populated
# In stage 16: transferred 4 clusters with 5 clusters populated
# In stage 17: transferred 4 clusters with 5 clusters populated
# In stage 18: transferred 2 clusters with 5 clusters populated
# In stage 19: transferred 4 clusters with 5 clusters populated
# In stage 20: transferred 5 clusters with 5 clusters populated
# In stage 21: transferred 4 clusters with 5 clusters populated
# In stage 22: transferred 3 clusters with 5 clusters populated
# In stage 23: transferred 6 clusters with 5 clusters populated
# In stage 24: transferred 6 clusters with 5 clusters populated
# In stage 25: transferred 5 clusters with 5 clusters populated
# In stage 26: transferred 3 clusters with 5 clusters populated
# In stage 27: transferred 3 clusters with 5 clusters populated
# In stage 28: transferred 3 clusters with 5 clusters populated
# In stage 29: transferred 6 clusters with 5 clusters populated
#
# Cluster 3: [('universidad', 1440), ('literatura', 853), ('nacional', 590), ('escritora', 519), ('estudios', 445)]
#
# Cluster 2: [('libro', 527), ('novela', 501), ('obra', 442), ('años', 433), ('poesía', 360)]
#
# Cluster 1: [('años', 399), ('mujeres', 244), ('nacional', 229), ('mujer', 210), ('año', 205)]
#
# Cluster 0: [('poesía', 426), ('libro', 359), ('premio', 347), ('obra', 257), ('méxico', 247)]
#
# Cluster 4: [('em', 394), ('do', 280), ('da', 272), ('reimpresión', 232), ('com', 182)]
# In stage 0: transferred 6 clusters with 5 clusters populated
# In stage 1: transferred 1 clusters with 5 clusters populated
# In stage 2: transferred 0 clusters with 5 clusters populated
# In stage 3: transferred 0 clusters with 5 clusters populated
# In stage 4: transferred 0 clusters with 5 clusters populated
# In stage 5: transferred 1 clusters with 5 clusters populated
# In stage 6: transferred 1 clusters with 5 clusters populated
# In stage 7: transferred 1 clusters with 5 clusters populated
# In stage 8: transferred 1 clusters with 5 clusters populated
# In stage 9: transferred 0 clusters with 5 clusters populated
# In stage 10: transferred 0 clusters with 5 clusters populated
# In stage 11: transferred 0 clusters with 5 clusters populated
# In stage 12: transferred 0 clusters with 5 clusters populated
# In stage 13: transferred 0 clusters with 5 clusters populated
# In stage 14: transferred 0 clusters with 5 clusters populated
# In stage 15: transferred 0 clusters with 5 clusters populated
# In stage 16: transferred 1 clusters with 5 clusters populated
# In stage 17: transferred 1 clusters with 5 clusters populated
# In stage 18: transferred 0 clusters with 5 clusters populated
# In stage 19: transferred 0 clusters with 5 clusters populated
# In stage 20: transferred 0 clusters with 5 clusters populated
# In stage 21: transferred 0 clusters with 5 clusters populated
# In stage 22: transferred 0 clusters with 5 clusters populated
# In stage 23: transferred 0 clusters with 5 clusters populated
# In stage 24: transferred 0 clusters with 5 clusters populated
# In stage 25: transferred 1 clusters with 5 clusters populated
# In stage 26: transferred 1 clusters with 5 clusters populated
# In stage 27: transferred 0 clusters with 5 clusters populated
# Converged.  Breaking out.
#
# Cluster 3: [('universidad', 1440), ('literatura', 854), ('nacional', 590), ('escritora', 520), ('estudios', 445)]
#
# Cluster 2: [('libro', 527), ('novela', 501), ('obra', 442), ('años', 433), ('poesía', 360)]
#
# Cluster 1: [('años', 399), ('mujeres', 244), ('nacional', 229), ('mujer', 210), ('año', 205)]
#
# Cluster 0: [('poesía', 426), ('libro', 359), ('premio', 347), ('obra', 257), ('méxico', 247)]
#
# Cluster 4: [('em', 394), ('do', 280), ('da', 272), ('reimpresión', 232), ('com', 182)]
# In stage 0: transferred 17 clusters with 5 clusters populated
# In stage 1: transferred 4 clusters with 5 clusters populated
# In stage 2: transferred 2 clusters with 5 clusters populated
# In stage 3: transferred 3 clusters with 5 clusters populated
# In stage 4: transferred 2 clusters with 5 clusters populated
# In stage 5: transferred 3 clusters with 5 clusters populated
# In stage 6: transferred 3 clusters with 5 clusters populated
# In stage 7: transferred 3 clusters with 5 clusters populated
# In stage 8: transferred 2 clusters with 5 clusters populated
# In stage 9: transferred 4 clusters with 5 clusters populated
# In stage 10: transferred 4 clusters with 5 clusters populated
# In stage 11: transferred 2 clusters with 5 clusters populated
# In stage 12: transferred 3 clusters with 5 clusters populated
# In stage 13: transferred 5 clusters with 5 clusters populated
# In stage 14: transferred 2 clusters with 5 clusters populated
# In stage 15: transferred 2 clusters with 5 clusters populated
# In stage 16: transferred 4 clusters with 5 clusters populated
# In stage 17: transferred 3 clusters with 5 clusters populated
# In stage 18: transferred 2 clusters with 5 clusters populated
# In stage 19: transferred 4 clusters with 5 clusters populated
# In stage 20: transferred 2 clusters with 5 clusters populated
# In stage 21: transferred 2 clusters with 5 clusters populated
# In stage 22: transferred 3 clusters with 5 clusters populated
# In stage 23: transferred 3 clusters with 5 clusters populated
# In stage 24: transferred 1 clusters with 5 clusters populated
# In stage 25: transferred 3 clusters with 5 clusters populated
# In stage 26: transferred 3 clusters with 5 clusters populated
# In stage 27: transferred 3 clusters with 5 clusters populated
# In stage 28: transferred 2 clusters with 5 clusters populated
# In stage 29: transferred 2 clusters with 5 clusters populated
#
# Cluster 3: [('universidad', 1441), ('literatura', 857), ('nacional', 592), ('escritora', 521), ('estudios', 445)]
#
# Cluster 2: [('libro', 527), ('novela', 501), ('obra', 442), ('años', 434), ('poesía', 360)]
#
# Cluster 1: [('años', 399), ('mujeres', 244), ('nacional', 229), ('mujer', 210), ('año', 205)]
#
# Cluster 0: [('poesía', 428), ('libro', 359), ('premio', 347), ('obra', 258), ('méxico', 248)]
#
# Cluster 4: [('em', 394), ('do', 280), ('da', 272), ('reimpresión', 232), ('com', 182)]

# %% [markdown]
# ### Training Topic Modeling with `GSDMM` (Gibbs Sampling algorithm for the Dirichlet Multinomial Mixture)

# %%
text = re.sub(r'(^.*?\))', '', entries[0])

# Tokenize text into sentences
sents = sent_tokenize(text)
# Tokenize sentences into words
data = list(process.sent_to_words(sents))
# Remove stopwords in Spanish
docs = process.remove_stopwords(data)
# Filter unique words
vocab = set(x for doc in docs for x in doc)

# %%
mgp = MovieGroupProcess(K=5, alpha=0.1, beta=0.1, n_iters=30)
y = mgp.fit(docs, len(vocab))
# Out:
# In stage 0: transferred 14 clusters with 4 clusters populated
# In stage 1: transferred 7 clusters with 5 clusters populated
# In stage 2: transferred 3 clusters with 4 clusters populated
# In stage 3: transferred 7 clusters with 4 clusters populated
# In stage 4: transferred 7 clusters with 5 clusters populated
# In stage 5: transferred 7 clusters with 5 clusters populated
# In stage 6: transferred 8 clusters with 5 clusters populated
# In stage 7: transferred 7 clusters with 5 clusters populated
# In stage 8: transferred 8 clusters with 5 clusters populated
# In stage 9: transferred 5 clusters with 5 clusters populated
# In stage 10: transferred 8 clusters with 5 clusters populated
# In stage 11: transferred 5 clusters with 5 clusters populated
# In stage 12: transferred 5 clusters with 5 clusters populated
# In stage 13: transferred 7 clusters with 5 clusters populated
# In stage 14: transferred 6 clusters with 5 clusters populated
# In stage 15: transferred 9 clusters with 4 clusters populated
# In stage 16: transferred 9 clusters with 5 clusters populated
# In stage 17: transferred 6 clusters with 5 clusters populated
# In stage 18: transferred 6 clusters with 5 clusters populated
# In stage 19: transferred 4 clusters with 5 clusters populated
# In stage 20: transferred 7 clusters with 4 clusters populated
# In stage 21: transferred 7 clusters with 4 clusters populated
# In stage 22: transferred 8 clusters with 5 clusters populated
# In stage 23: transferred 4 clusters with 5 clusters populated
# In stage 24: transferred 7 clusters with 4 clusters populated
# In stage 25: transferred 4 clusters with 5 clusters populated
# In stage 26: transferred 5 clusters with 5 clusters populated
# In stage 27: transferred 4 clusters with 5 clusters populated
# In stage 28: transferred 5 clusters with 5 clusters populated
# In stage 29: transferred 8 clusters with 4 clusters populated

# %%
# Define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    top_words = []
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        top_words.append(sort_dicts)
        print("\nCluster %s: %s"%(cluster, sort_dicts))
    return top_words
# Number of documents per topic
doc_count = np.array(mgp.cluster_doc_count)
# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-15:][::-1]

# Get top words in topics
top_words = top_words(mgp.cluster_word_distribution, top_index, 3)
# Out:
# Cluster 1: [('mujeres', 3), ('poetas', 3), ('país', 3)]
#
# Cluster 4: [('poesía', 3), ('casa', 2), ('nacional', 2)]
#
# Cluster 0: [('antología', 5), ('asociación', 4), ('escritores', 4)]
#
# Cluster 2: [('internacional', 3), ('poesía', 3), ('feria', 2)]
#
# Cluster 3: []

# %%
clusters = []
for sublist in top_words:
    clusters.append(list(map(lambda x: x[0], sublist)))
clusters = [item for sublist in clusters for item in sublist]
clusters
# Out:
# ['mujeres',
#  'poetas',
#  'país',
#  'poesía',
#  'casa',
#  'nacional',
#  'antología',
#  'asociación',
#  'escritores',
#  'internacional',
#  'poesía',
#  'feria']

# %% [markdown]
# ### Bibliography:
# - [GSDMM: Short text clustering](https://github.com/rwalk/gsdmm)
